# %% [markdown]
# #### Import packages that will be used

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium
from sklearn.cluster import KMeans

# %% [markdown]
# #### read in csv from previous notebook

# %%
Toronto = pd.read_csv("Toronto.csv")
#Toronto

# %% [markdown]
# #### See how many neighborhoods and boroughs there are

# %%
print("The dataframe has {} Boroughs and {} Neighborhoods.".format(
        len(Toronto["Borough"].unique()),
        Toronto.shape[0]
    )
)
# Out:
# The dataframe has 10 Boroughs and 102 Neighborhoods.

# %% [markdown]
# #### Get coordinates for Toronto for our basemap

# %%
address = "Toronto, ON"

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto ON is {}, {}.'.format(latitude, longitude))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# The geograpical coordinates of Toronto ON is 43.653963, -79.387207.

# %% [markdown]
# #### Create a map of Toronto with Neighborhoods signified as points <- Note I used Stamen Toner as basemap tile to show contrast

# %%
#toronto_location = [43.653963, -79.387207]
toronto_location = [latitude, longitude]

toronto_map = folium.Map(location=toronto_location, tiles="Stamen Toner", zoom_start=10)

for lat, lng, borough, neighborhood, ps_code in zip(Toronto["Latitude"], Toronto["Longitude"], Toronto["Borough"],Toronto["Neighborhood"], Toronto["Postal Code"]):
    label = '{}, {}'.format(ps_code, neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(toronto_map)

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Examine the head of the dataset

# %%
Toronto.head(5)
# Out:
#   Postal Code      Borough                            Neighborhood   Latitude  \
# 0         M1B  Scarborough                          Rouge, Malvern  43.806686
# 1         M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3         M1G  Scarborough                                  Woburn  43.770992
# 4         M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# #### See Neighborhood and Postcode distribution

# %%
Toronto.groupby("Borough").count()
# Out:
#                   Postal Code  Neighborhood  Latitude  Longitude
# Borough
# Central Toronto             9             9         9          9
# Downtown Toronto           18            18        18         18
# East Toronto                5             5         5          5
# East York                   5             5         5          5
# Etobicoke                  12            12        12         12
# North York                 24            24        24         24
# Queen's Park                1             1         1          1
# Scarborough                17            17        17         17
# West Toronto                6             6         6          6
# York                        5             5         5          5

# %%
Toronto_grouped = Toronto.groupby("Neighborhood").mean().reset_index()
Toronto_grouped
# Out:
#                                           Neighborhood   Latitude  Longitude
# 0                             Adelaide, King, Richmond  43.650571 -79.384568
# 1                                            Agincourt  43.794200 -79.262029
# 2    Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 3    Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 4                               Alderwood, Long Branch  43.602414 -79.543484
# 5      Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 6                                      Bayview Village  43.786947 -79.385975
# 7                    Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 8                                          Berczy Park  43.644771 -79.373306
# 9                          Birch Cliff, Cliffside West  43.692657 -79.264848
# 10   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 11        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 12                         CFB Toronto, Downsview East  43.737473 -79.464763
# 13   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 14                         Cabbagetown, St. James Town  43.667967 -79.367675
# 15                                 Caledonia-Fairbanks  43.689026 -79.453512
# 16                                           Cedarbrae  43.773136 -79.239476
# 17                                  Central Bay Street  43.657952 -79.387383
# 18           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 19                                            Christie  43.669542 -79.422564
# 20                                Church and Wellesley  43.665860 -79.383160
# 21                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 22             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 23     Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 24   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 25                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 26                                          Davisville  43.704324 -79.388790
# 27                                    Davisville North  43.712751 -79.390197
# 28   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 29      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 30            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 31                                     Don Mills North  43.745906 -79.352188
# 32   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 33                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 34                                   Downsview Central  43.728496 -79.495697
# 35                                 Downsview Northwest  43.761631 -79.520999
# 36                                      Downsview West  43.739015 -79.506944
# 37         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 38                                        East Toronto  43.685347 -79.338106
# 39                                             Eastern  43.662744 -79.321558
# 40                                    Emery, Humberlea  43.724766 -79.532242
# 41                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 42              First Canadian Place, Underground city  43.648429 -79.382280
# 43                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 44                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 45                                           Glencairn  43.709577 -79.445073
# 46                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 47                      Harbord, University of Toronto  43.662696 -79.400049
# 48   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 49                           Harbourfront, Regent Park  43.654260 -79.360636
# 50                       High Park, The Junction South  43.661608 -79.464763
# 51              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 52                                   Hillcrest Village  43.803762 -79.363452
# 53        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 54   Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 55                                       Humber Summit  43.756303 -79.565963
# 56                                  Humewood-Cedarvale  43.693781 -79.428191
# 57                                    Islington Avenue  43.667856 -79.532242
# 58   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 59   Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
# 60                       L'Amoreaux West, Steeles West  43.799525 -79.318389
# 61                    Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 62                                       Lawrence Park  43.728020 -79.388790
# 63                                             Leaside  43.709060 -79.363452
# 64                            Little Portugal, Trinity  43.647927 -79.419750
# 65            Maple Leaf Park, North Park, Upwood Park  43.713756 -79.490074
# 66                                   Maryvale, Wexford  43.750071 -79.295849
# 67                         Moore Park, Summerhill East  43.689574 -79.383160
# 68                             Newtonbrook, Willowdale  43.789053 -79.408493
# 69                                  North Toronto West  43.715383 -79.405678
# 70                                           Northwest  43.706748 -79.594054
# 71                     Northwood Park, York University  43.767980 -79.487262
# 72                                        Not assigned  43.662301 -79.389494
# 73                              Parkdale, Roncesvalles  43.648960 -79.456325
# 74                                           Parkwoods  43.753259 -79.329656
# 75                                            Rosedale  43.679563 -79.377529
# 76                                            Roselawn  43.711695 -79.416936
# 77                                      Rouge, Malvern  43.806686 -79.194353
# 78                                  Runnymede, Swansea  43.651571 -79.484450
# 79                            Ryerson, Garden District  43.657162 -79.378937
# 80                                 Scarborough Village  43.744734 -79.239476
# 81                            Silver Hills, York Mills  43.757490 -79.374714
# 82                                      St. James Town  43.651494 -79.375418
# 83                                     Studio District  43.659526 -79.340923
# 84                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 85                                         The Beaches  43.676357 -79.293031
# 86                      The Beaches West, India Bazaar  43.668999 -79.315572
# 87                        The Danforth West, Riverdale  43.679557 -79.352188
# 88                                       The Esplanade  43.646435 -79.374846
# 89                       The Junction North, Runnymede  43.673185 -79.487262
# 90       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 91                                    Thorncliffe Park  43.705369 -79.349372
# 92                                         Upper Rouge  43.836125 -79.205636
# 93                                    Victoria Village  43.725882 -79.315572
# 94                                           Westmount  43.696319 -79.532242
# 95                                              Weston  43.706876 -79.518188
# 96                                    Willowdale South  43.770120 -79.408493
# 97                                     Willowdale West  43.782736 -79.442259
# 98                                              Woburn  43.770992 -79.216917
# 99                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 100                                   Woodbine Heights  43.695344 -79.318389
# 101                                    York Mills West  43.752758 -79.400049

# %% [markdown]
# #### Lets try clustering the neighborhoods <- there are ten boroughs so lets try ten clusters

# %%
# set number of clusters
kclusters = 10

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 9, 9, 0, 4, 6, 7, 6, 3, 1])

# %% [markdown]
# #### Examine the head and tail of the cluster dataframe

# %%
Toronto_merged = Toronto

# add clustering labels
Toronto_merged['Cluster Labels'] = kmeans.labels_

Toronto_merged.head()
# Out:
#   Postal Code      Borough                            Neighborhood   Latitude  \
# 0         M1B  Scarborough                          Rouge, Malvern  43.806686
# 1         M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3         M1G  Scarborough                                  Woburn  43.770992
# 4         M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Cluster Labels
# 0 -79.194353               3
# 1 -79.160497               9
# 2 -79.188711               9
# 3 -79.216917               0
# 4 -79.239476               4

# %%
Toronto_merged.tail()
# Out:
#     Postal Code    Borough                                       Neighborhood  \
# 97          M9N       York                                             Weston
# 98          M9P  Etobicoke                                          Westmount
# 99          M9R  Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 100         M9V  Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
# 101         M9W  Etobicoke                                          Northwest
#
#       Latitude  Longitude  Cluster Labels
# 97   43.706876 -79.518188               7
# 98   43.696319 -79.532242               2
# 99   43.688905 -79.554724               1
# 100  43.739416 -79.588437               1
# 101  43.706748 -79.594054               7

# %% [markdown]
# #### Lets map the clusters

# %%
map_clusters = folium.Map(location=toronto_location, zoom_start=10)

x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, Boro, PostC, cluster in zip(Toronto_merged["Latitude"], Toronto_merged["Longitude"], Toronto_merged["Borough"], 
                                  Toronto_merged["Postal Code"], Toronto_merged["Neighborhood"], Toronto_merged["Cluster Labels"]):
    label = folium.Popup(str(poi) + " Cluster " + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Now lets examine cluster membership

# %% [markdown]
# #### Cluster 1

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                            Neighborhood  Cluster Labels
# 3        Scarborough                                  Woburn               0
# 55  Downtown Toronto                          St. James Town               0
# 58  Downtown Toronto                Adelaide, King, Richmond               0
# 70  Downtown Toronto  First Canadian Place, Underground city               0

# %% [markdown]
# #### Cluster 2

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#           Borough                                       Neighborhood  \
# 9     Scarborough                        Birch Cliff, Cliffside West
# 21     North York                            Newtonbrook, Willowdale
# 38      East York                                            Leaside
# 39      East York                                   Thorncliffe Park
# 43   East Toronto                                    Studio District
# 83   West Toronto                             Parkdale, Roncesvalles
# 85   Queen's Park                                       Not assigned
# 86   East Toronto                                            Eastern
# 87      Etobicoke       Humber Bay Shores, Mimico South, New Toronto
# 91      Etobicoke  Kingsway Park South West, Mimico NW, The Queen...
# 93      Etobicoke  Cloverdale, Islington, Martin Grove, Princess ...
# 99      Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 100     Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
#
#      Cluster Labels
# 9                 1
# 21                1
# 38                1
# 39                1
# 43                1
# 83                1
# 85                1
# 86                1
# 87                1
# 91                1
# 93                1
# 99                1
# 100               1

# %% [markdown]
# #### Note the Queen's Park Borough in the cluster above (This is an actual park so probably not a good Borough to examine further)

# %% [markdown]
# #### Cluster 3

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                 Neighborhood  Cluster Labels
# 46   Central Toronto           North Toronto West               2
# 51  Downtown Toronto  Cabbagetown, St. James Town               2
# 77      West Toronto     Little Portugal, Trinity               2
# 92         Etobicoke             Islington Avenue               2
# 98         Etobicoke                    Westmount               2

# %% [markdown]
# #### Cluster 4

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                                       Neighborhood  \
# 0        Scarborough                                     Rouge, Malvern
# 8        Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 13       Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# 14       Scarborough  Agincourt North, L'Amoreaux East, Milliken, St...
# 17        North York                                  Hillcrest Village
# 18        North York                       Fairview, Henry Farm, Oriole
# 20        North York                           Silver Hills, York Mills
# 25        North York                                          Parkwoods
# 30        North York                        CFB Toronto, Downsview East
# 42      East Toronto                     The Beaches West, India Bazaar
# 47   Central Toronto                                         Davisville
# 48   Central Toronto                        Moore Park, Summerhill East
# 49   Central Toronto  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 67  Downtown Toronto          Chinatown, Grange Park, Kensington Market
# 72        North York                                          Glencairn
# 75  Downtown Toronto                                           Christie
# 79        North York           Maple Leaf Park, North Park, Upwood Park
# 82      West Toronto                      High Park, The Junction South
# 84      West Toronto                                 Runnymede, Swansea
# 88         Etobicoke                             Alderwood, Long Branch
#
#     Cluster Labels
# 0                3
# 8                3
# 13               3
# 14               3
# 17               3
# 18               3
# 20               3
# 25               3
# 30               3
# 42               3
# 47               3
# 48               3
# 49               3
# 67               3
# 72               3
# 75               3
# 79               3
# 82               3
# 84               3
# 88               3

# %% [markdown]
# #### Cluster 5

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                                       Neighborhood  \
# 4        Scarborough                                          Cedarbrae
# 10       Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 24        North York                                    Willowdale West
# 53  Downtown Toronto                          Harbourfront, Regent Park
# 54  Downtown Toronto                           Ryerson, Garden District
# 57  Downtown Toronto                                 Central Bay Street
# 59  Downtown Toronto  Harbourfront East, Toronto Islands, Union Station
# 78      West Toronto       Brockton, Exhibition Place, Parkdale Village
# 89         Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# 90         Etobicoke  Humber Bay, King's Mill Park, Kingsway Park So...
#
#     Cluster Labels
# 4                4
# 10               4
# 24               4
# 53               4
# 54               4
# 57               4
# 59               4
# 78               4
# 89               4
# 90               4

# %% [markdown]
# #### Cluster 6

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 5,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                                       Neighborhood  \
# 12       Scarborough                                          Agincourt
# 29        North York                    Northwood Park, York University
# 34        North York                                   Victoria Village
# 35         East York                    Woodbine Gardens, Parkview Hill
# 36         East York                                   Woodbine Heights
# 40         East York                                       East Toronto
# 61  Downtown Toronto                     Commerce Court, Victoria Hotel
# 65   Central Toronto                The Annex, North Midtown, Yorkville
# 71        North York                   Lawrence Heights, Lawrence Manor
# 94         Etobicoke  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 95        North York                                      Humber Summit
#
#     Cluster Labels
# 12               5
# 29               5
# 34               5
# 35               5
# 36               5
# 40               5
# 61               5
# 65               5
# 71               5
# 94               5
# 95               5

# %% [markdown]
# #### Cluster 7

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 6,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                                     Neighborhood  \
# 5        Scarborough                              Scarborough Village
# 7        Scarborough                  Clairlea, Golden Mile, Oakridge
# 26        North York                                  Don Mills North
# 27        North York                 Flemingdon Park, Don Mills South
# 28        North York  Bathurst Manor, Downsview North, Wilson Heights
# 44   Central Toronto                                    Lawrence Park
# 45   Central Toronto                                 Davisville North
# 56  Downtown Toronto                                      Berczy Park
# 62        North York                Bedford Park, Lawrence Manor East
# 63   Central Toronto                                         Roselawn
# 69  Downtown Toronto                                    The Esplanade
# 76      West Toronto                     Dovercourt Village, Dufferin
#
#     Cluster Labels
# 5                6
# 7                6
# 26               6
# 27               6
# 28               6
# 44               6
# 45               6
# 56               6
# 62               6
# 63               6
# 69               6
# 76               6

# %% [markdown]
# #### Cluster 8

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 7,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#               Borough                                       Neighborhood  \
# 6         Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 31         North York                                     Downsview West
# 41       East Toronto                       The Danforth West, Riverdale
# 52   Downtown Toronto                               Church and Wellesley
# 68   Downtown Toronto  CN Tower, Bathurst Quay, Island airport, Harbo...
# 81               York                      The Junction North, Runnymede
# 96         North York                                   Emery, Humberlea
# 97               York                                             Weston
# 101         Etobicoke                                          Northwest
#
#      Cluster Labels
# 6                 7
# 31                7
# 41                7
# 52                7
# 68                7
# 81                7
# 96                7
# 97                7
# 101               7

# %% [markdown]
# #### Cluster 9

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 8,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                         Neighborhood  Cluster Labels
# 11       Scarborough                    Maryvale, Wexford               8
# 15       Scarborough        L'Amoreaux West, Steeles West               8
# 19        North York                      Bayview Village               8
# 33        North York                  Downsview Northwest               8
# 50  Downtown Toronto                             Rosedale               8
# 64   Central Toronto  Forest Hill North, Forest Hill West               8
# 73              York                   Humewood-Cedarvale               8

# %% [markdown]
# #### Cluster 10

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 9,
                     Toronto_merged.columns[[1,2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#              Borough                                    Neighborhood  \
# 1        Scarborough          Highland Creek, Rouge Hill, Port Union
# 2        Scarborough               Guildwood, Morningside, West Hill
# 16       Scarborough                                     Upper Rouge
# 22        North York                                Willowdale South
# 23        North York                                 York Mills West
# 32        North York                               Downsview Central
# 37      East Toronto                                     The Beaches
# 60  Downtown Toronto        Design Exchange, Toronto Dominion Centre
# 66  Downtown Toronto                  Harbord, University of Toronto
# 74              York                             Caledonia-Fairbanks
# 80              York  Del Ray, Keelesdale, Mount Dennis, Silverthorn
#
#     Cluster Labels
# 1                9
# 2                9
# 16               9
# 22               9
# 23               9
# 32               9
# 37               9
# 60               9
# 66               9
# 74               9
# 80               9

# %% [markdown]
# #### It looks like the clusters are fairly evenly distributed geographically
# So I will use the two most geographically distant Boroughs ("Etobicoke" and "Scarborough") in further weeks to act as a random sample of Toronto Boroughs (and subsequently Neighborhoods).

# %% [markdown]
# #### Lets visualize the clusters one more time to remind you (the viewer) of their distribution

# %%
map_clusters = folium.Map(location=toronto_location, tiles="Stamen Toner", zoom_start=10)

x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, Boro, PostC, cluster in zip(Toronto_merged["Latitude"], Toronto_merged["Longitude"], Toronto_merged["Borough"], 
                                  Toronto_merged["Postal Code"], Toronto_merged["Neighborhood"], Toronto_merged["Cluster Labels"]):
    label = folium.Popup(str(poi) + " Cluster " + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Thanks for reviewing my notebook
